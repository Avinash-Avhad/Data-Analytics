# %% [markdown]
# # Divali_Sales_Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel("Diwali Sales Data (3) 01 (1).xlsx")
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()# dtype=object=categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# drop unwanted columns
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
pd.isnull(df).sum()# check for null values
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# change Data Type
df['Amount']=df['Amount'].astype('int')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.describe()# describe method returns description of data in the dataframe
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#use describe for specific columns
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Gender

# %%
# plotting the bar charts for Gender and it's count
ax=sns.countplot(data=df,x='Gender')#male, #countplot is use for univariate analysis

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting the bar chart for Gender VS Total amount

sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(sales_gen)
# as_index use for not get default index
ax=sns.barplot(x='Gender',y='Amount',data=sales_gen)

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %% [markdown]
# from above graphs we can see that most of the buyers are female and even the purchasing power of females are greater than men

# %% [markdown]
# Age

# %%
s=df['Age Group'].sort_index(axis=0,ascending=False)
ax=sns.countplot(data=df,x=s,hue='Gender')#male,Female

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Total Amount VS Age Group
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(sales_age)
sns.barplot(x='Age Group',y='Amount',data=sales_age)
plt.figure(figsize=(15,8))
x=sns.barplot(x='Age Group',y='Amount',data=sales_age)
for i in x.containers:
    x.bar_label(i)
# Out:
#   Age Group    Amount
# 2     26-35  42613442
# 3     36-45  22144994
# 1     18-25  17240732
# 4     46-50   9207844
# 5     51-55   8261477
# 6       55+   4080987
# 0      0-17   2699653

# %% [markdown]
# From above Graph we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# State

# %%
#Total no of orders from top 10 states
sales_state=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False)
print(sales_state)
# as_index use for not ged default index
sns.set(rc={'figure.figsize':(25,10)})
sns.barplot(x='State',y='Orders',data=sales_state)
# Out:
#                State  Orders
# 14     Uttar Pradesh    4807
# 10       Maharashtra    3810
# 7          Karnataka    3240
# 2              Delhi    2740
# 9     Madhya Pradesh    2252
# 0     Andhra Pradesh    2051
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1066
# 1              Bihar    1062
# 6          Jharkhand     953
# 15       Uttarakhand     824
# 12         Rajasthan     555
# 11            Punjab     495
# 13         Telangana     312
# <AxesSubplot:xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states
sales_state=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(sales_state)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State',y='Amount',data=sales_state)

plt.figure(figsize=(25,12))
x=sns.barplot(x='State',y='Amount',data=sales_state)
for i in x.containers:
    x.bar_label(i)
# Out:
#                State    Amount
# 14     Uttar Pradesh  19374968
# 10       Maharashtra  14427543
# 7          Karnataka  13523540
# 2              Delhi  11603818
# 9     Madhya Pradesh   8101142
# 0     Andhra Pradesh   8037146
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3946082
# 8             Kerala   3894491
# 6          Jharkhand   3026456
# 15       Uttarakhand   2520944
# 12         Rajasthan   1909409
# 11            Punjab   1525800
# 13         Telangana   1151490

# %% [markdown]
# From Above Graph we can see that most of the orders and total sale/amount are from utter pradesh, maharashtra and karnataka respectively

# %% [markdown]
# Marital Status

# %%
ax=sns.countplot(data=df,x='Marital_Status')
sns.set(rc={'figure.figsize':(15,10)})
for i in ax.containers:
    ax.bar_label(i)
#0=> maried
#1=> Unmaried

# %%
sales_state=df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(sales_state)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marital_Status',y='Amount',data=sales_state,hue='Gender')
# Out:
#    Marital_Status Gender    Amount
# 0               0      F  43786646
# 2               1      F  30549207
# 1               0      M  18338738
# 3               1      M  13574538
# <AxesSubplot:xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From above Graph we can see that most of the buyers are married(women) and they have high purchesing power

# %% [markdown]
# Occupation

# %%
sns.set(rc={'figure.figsize':(15,10)})
ax=sns.countplot(data=df,x='Occupation')
for i in ax.containers:
    ax.bar_label(i)

# %%
sales_state=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(sales_state)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Occupation',y='Amount',data=sales_state)
# Out:
#          Occupation    Amount
# 10        IT Sector  14755079
# 8        Healthcare  13034586
# 2          Aviation  12602298
# 3           Banking  10770610
# 7              Govt   8517212
# 9       Hospitality   6376405
# 12            Media   6295832
# 1        Automobile   5368596
# 4          Chemical   5297436
# 11           Lawyer   4981665
# 13           Retail   4783170
# 6   Food Processing   4070670
# 5      Construction   3597511
# 14          Textile   3204972
# 0       Agriculture   2593087
# <AxesSubplot:xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From Above Graph we can see that most of the buyers are working in IT ,Healthcare And Aviation Sector

# %% [markdown]
# Product Category

# %%
sns.set(rc={'figure.figsize':(25,10)})
ax=sns.countplot(data=df,x='Product_Category')
for i in ax.containers:
    ax.bar_label(i)

# %%
sales_state=df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(sales_state)
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(x='Product_Category',y='Amount',data=sales_state)
# Out:
#          Product_Category    Amount
# 6                    Food  33933883
# 3      Clothing & Apparel  16495019
# 5   Electronics & Gadgets  15643846
# 7        Footwear & Shoes  15575209
# 8               Furniture   5440051
# 9            Games & Toys   4331694
# 14        Sports Products   3635933
# 1                  Beauty   1959484
# 0                    Auto   1958609
# 15             Stationery   1676051
# 11        Household items   1569337
# 16             Tupperware   1155642
# 2                   Books   1061478
# 4                   Decor    730360
# 13               Pet Care    482277
# 10     Hand & Power Tools    405618
# 17             Veterinary    112702
# 12                 Office     81936
# <AxesSubplot:xlabel='Product_Category', ylabel='Amount'>

# %%
sales_state=df.groupby(['Product_Category'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False)
print(sales_state)
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(x='Product_Category',y='Orders',data=sales_state)
# Out:
#          Product_Category  Orders
# 3      Clothing & Apparel    6634
# 6                    Food    6110
# 5   Electronics & Gadgets    5226
# 7        Footwear & Shoes    2646
# 11        Household items    1331
# 1                  Beauty    1086
# 9            Games & Toys     940
# 8               Furniture     889
# 14        Sports Products     870
# 13               Pet Care     536
# 15             Stationery     281
# 12                 Office     261
# 2                   Books     245
# 0                    Auto     239
# 4                   Decor     235
# 17             Veterinary     206
# 16             Tupperware     166
# 10     Hand & Power Tools      80
# <AxesSubplot:xlabel='Product_Category', ylabel='Orders'>

# %% [markdown]
# From Above graph we can see that Most of the sold product are from food,clothing and Electronics Category

# %% [markdown]
# # Conclusion :

# %% [markdown]
# Married women group 26-35 yrs from UP,Maharashtra And Karnataka working in IT,Helthcare and Aviation are More likely to buy products from Food,Clothing and Electronocs Category
